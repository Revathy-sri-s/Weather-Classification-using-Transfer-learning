# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-price-dataset-of-india/House Price India.csv

# %%
vg_df = pd.read_csv('/kaggle/input/house-price-dataset-of-india/House Price India.csv')

# %%
vg_df.head(7)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
# 5  6762813105  42491                   3                 2.50         2600
# 6  6762813157  42491                   5                 3.25         3660
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
# 5      4750               1.0                   0                0
# 6     11995               2.0                   0                2
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
# 3                       3  ...        2001                0       122005
# 4                       4  ...        1929                0       122006
# 5                       4  ...        1951                0       122007
# 6                       3  ...        2006                0       122008
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
# 2    52.8852   -114.468               2940            6600
# 3    52.9532   -114.321               3350           42847
# 4    52.9047   -114.485               2060            4500
# 5    52.9133   -114.590               2380            4750
# 6    52.7637   -114.050               3320           11241
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# 2                         1                         53  1200000
# 3                         3                         76   838000
# 4                         1                         51   805000
# 5                         1                         67   790000
# 6                         3                         72   785000
#
# [7 rows x 23 columns]

# %%
#MATPLOTLIB
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#SEABORN
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#MATPLOTLIB
import matplotlib.pyplot as plt
# %matplotlib inline
#SEABORN
import seaborn as sns

# %%
plt.hist(vg_df['number of bathrooms'])
# Out:
# (array([2.559e+03, 3.037e+03, 6.379e+03, 1.765e+03, 6.860e+02, 1.450e+02,
#         3.500e+01, 7.000e+00, 3.000e+00, 4.000e+00]),
#  array([0.5 , 1.25, 2.  , 2.75, 3.5 , 4.25, 5.  , 5.75, 6.5 , 7.25, 8.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(vg_df.Lattitude,vg_df.Longitude)

# %%
plt.scatter(vg_df.living_area_renov,vg_df.lot_area_renov)

# %%
vg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
#  10  grade of the house                     14620 non-null  int64
#  11  Area of the house(excluding basement)  14620 non-null  int64
#  12  Area of the basement                   14620 non-null  int64
#  13  Built Year                             14620 non-null  int64
#  14  Renovation Year                        14620 non-null  int64
#  15  Postal Code                            14620 non-null  int64
#  16  Lattitude                              14620 non-null  float64
#  17  Longitude                              14620 non-null  float64
#  18  living_area_renov                      14620 non-null  int64
#  19  lot_area_renov                         14620 non-null  int64
#  20  Number of schools nearby               14620 non-null  int64
#  21  Distance from the airport              14620 non-null  int64
#  22  Price                                  14620 non-null  int64
# dtypes: float64(4), int64(19)
# memory usage: 2.6 MB

# %%
pd.plotting.scatter_matrix(vg_df.loc[:,"Date":"Price"],diagonal="kde",figsize=(20,15))
plt.show()

# %%
pd.DataFrame(vg_df.iloc[:,0:21].mean().to_frame()).T
# Out:
#              id          Date  number of bedrooms  number of bathrooms  \
# 0  6.762821e+09  42604.538646            3.379343             2.129583
#
#    living area      lot area  number of floors  waterfront present  \
# 0  2098.262996  15093.281122           1.50236            0.007661
#
#    number of views  condition of the house  ...  \
# 0         0.233105                3.430506  ...
#
#    Area of the house(excluding basement)  Area of the basement   Built Year  \
# 0                            1801.783926             296.47907  1970.926402
#
#    Renovation Year    Postal Code  Lattitude   Longitude  living_area_renov  \
# 0        90.924008  122033.062244  52.792848 -114.404007        1996.702257
#
#    lot_area_renov  Number of schools nearby
# 0    12753.500068                  2.012244
#
# [1 rows x 21 columns]

# %%
pd.DataFrame(vg_df.iloc[:,0:21].var().to_frame()).T
# Out:
#              id        Date  number of bedrooms  number of bathrooms  \
# 0  3.890734e+07  4535.75191            0.881193             0.592799
#
#     living area      lot area  number of floors  waterfront present  \
# 0  861695.81461  1.437898e+09          0.291858            0.007603
#
#    number of views  condition of the house  ...  \
# 0         0.587152                0.441097  ...
#
#    Area of the house(excluding basement)  Area of the basement  Built Year  \
# 0                          695239.054547          201198.36655  869.873918
#
#    Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0    173236.309226    364.13868   0.018912   0.019973      477610.040969
#
#    lot_area_renov  Number of schools nearby
# 0    6.790410e+08                  0.667953
#
# [1 rows x 21 columns]

# %%
pd.DataFrame(vg_df.iloc[:,0:21].median().to_frame()).T
# Out:
#              id     Date  number of bedrooms  number of bathrooms  \
# 0  6.762821e+09  42600.0                 3.0                 2.25
#
#    living area  lot area  number of floors  waterfront present  \
# 0       1930.0    7620.0               1.5                 0.0
#
#    number of views  condition of the house  ...  \
# 0              0.0                     3.0  ...
#
#    Area of the house(excluding basement)  Area of the basement  Built Year  \
# 0                                 1580.0                   0.0      1975.0
#
#    Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0              0.0     122032.0    52.8064   -114.421             1850.0
#
#    lot_area_renov  Number of schools nearby
# 0          7620.0                       2.0
#
# [1 rows x 21 columns]

# %%
vg_df.plot(x="Lattitude", y="Price")
IQR=vg_df["Price"].quantile(0.75)- vg_df["Price"].quantile(0.25)
IQR
# Out:
# 325000.0

# %%
range_price = vg_df["Price"].max() - vg_df["Price"].min()
print("The range of the Price level is:",range_price)
# Out:
# The range of the Price level is: 7622000

# %%
pd.DataFrame(vg_df.iloc[:,0:7].std().to_frame()).T
# Out:
#             id       Date  number of bedrooms  number of bathrooms  \
# 0  6237.574799  67.347991            0.938719             0.769934
#
#    living area      lot area  number of floors
# 0   928.275721  37919.621304          0.540239

# %%
print(vg_df['Price'].value_counts())
# Out:
# 450000    114
# 350000    113
# 400000    104
# 375000    103
# 550000    102
#          ...
# 561600      1
# 856500      1
# 907687      1
# 307999      1
# 146000      1
# Name: Price, Length: 2901, dtype: int64

# %%
vg_df.mode()
# Out:
#                id     Date  number of bedrooms  number of bathrooms  \
# 0      6762810020  42543.0                 3.0                  2.5
# 1      6762810021      NaN                 NaN                  NaN
# 2      6762810022      NaN                 NaN                  NaN
# 3      6762810023      NaN                 NaN                  NaN
# 4      6762810026      NaN                 NaN                  NaN
# ...           ...      ...                 ...                  ...
# 14615  6762831611      NaN                 NaN                  NaN
# 14616  6762831612      NaN                 NaN                  NaN
# 14617  6762831613      NaN                 NaN                  NaN
# 14618  6762831615      NaN                 NaN                  NaN
# 14619  6762831616      NaN                 NaN                  NaN
#
#        living area  lot area  number of floors  waterfront present  \
# 0           1400.0    5000.0               1.0                 0.0
# 1              NaN       NaN               NaN                 NaN
# 2              NaN       NaN               NaN                 NaN
# 3              NaN       NaN               NaN                 NaN
# 4              NaN       NaN               NaN                 NaN
# ...            ...       ...               ...                 ...
# 14615          NaN       NaN               NaN                 NaN
# 14616          NaN       NaN               NaN                 NaN
# 14617          NaN       NaN               NaN                 NaN
# 14618          NaN       NaN               NaN                 NaN
# 14619          NaN       NaN               NaN                 NaN
#
#        number of views  condition of the house  ...  Built Year  \
# 0                  0.0                     3.0  ...      2014.0
# 1                  NaN                     NaN  ...         NaN
# 2                  NaN                     NaN  ...         NaN
# 3                  NaN                     NaN  ...         NaN
# 4                  NaN                     NaN  ...         NaN
# ...                ...                     ...  ...         ...
# 14615              NaN                     NaN  ...         NaN
# 14616              NaN                     NaN  ...         NaN
# 14617              NaN                     NaN  ...         NaN
# 14618              NaN                     NaN  ...         NaN
# 14619              NaN                     NaN  ...         NaN
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 0                  0.0     122028.0    52.7745   -114.562             1440.0
# 1                  NaN          NaN    52.8834   -114.552                NaN
# 2                  NaN          NaN    52.8947        NaN                NaN
# 3                  NaN          NaN    52.9146        NaN                NaN
# 4                  NaN          NaN    52.9255        NaN                NaN
# ...                ...          ...        ...        ...                ...
# 14615              NaN          NaN        NaN        NaN                NaN
# 14616              NaN          NaN        NaN        NaN                NaN
# 14617              NaN          NaN        NaN        NaN                NaN
# 14618              NaN          NaN        NaN        NaN                NaN
# 14619              NaN          NaN        NaN        NaN                NaN
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0              5000.0                       3.0                       54.0
# 1                 NaN                       NaN                        NaN
# 2                 NaN                       NaN                        NaN
# 3                 NaN                       NaN                        NaN
# 4                 NaN                       NaN                        NaN
# ...               ...                       ...                        ...
# 14615             NaN                       NaN                        NaN
# 14616             NaN                       NaN                        NaN
# 14617             NaN                       NaN                        NaN
# 14618             NaN                       NaN                        NaN
# 14619             NaN                       NaN                        NaN
#
#           Price
# 0      450000.0
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 14615       NaN
# 14616       NaN
# 14617       NaN
# 14618       NaN
# 14619       NaN
#
# [14620 rows x 23 columns]
